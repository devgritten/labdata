# %%
import numpy as np

# %% [markdown]
# ##1. Criar um array com 10 números inteiros aleatórios entre 1 e 50 e calcular a média e o desvio padrão

# %%
array = np.random.randint(low=1, high=51, size=10)
print("Array {array} A média é {mean} e o desvio padrão {std}".format(array=array,
                                                                     mean=np.mean(array), 
                                                                     std=np.std(array))
                                                                    )
# Out:
# Array [11  5  5 16  1 36 19 13 42  4] A média é 15.2 e o desvio padrão 13.128594745821047

# %% [markdown]
# ##2. Criar um array de 10 números aleatórios e calcular a raiz quadrada de todos os valores menores ou iguais a 0,5

# %%
(lambda x: np.sqrt(x))(list(filter((lambda x: x <= 0.5),(np.random.rand(10)))))
# Out:
# Out[83]: array([0.69936553, 0.19668127, 0.19271241, 0.27007917, 0.6755369 ,
#        0.70309504])

# %% [markdown]
# ##3. Criar uma matriz 3D de tamanho 3x3x3 com valores aleatórios e exibir o valor máximo de cada linha de cada matriz 2D dentro dessa matriz 3D

# %%
matriz = np.random.rand(3,3,3)

for sub_matriz in matriz:
    for line in sub_matriz:
        print("O máximo da linha é {max}".format(max=max(line)))
# Out:
# O máximo da linha é 0.7920338204496951
# O máximo da linha é 0.8938550140125994
# O máximo da linha é 0.6919261468736262
# O máximo da linha é 0.7813191010128407
# O máximo da linha é 0.8498734517539219
# O máximo da linha é 0.564649106410601
# O máximo da linha é 0.24501946552845577
# O máximo da linha é 0.9928493159544999
# O máximo da linha é 0.6525033381314194

# %% [markdown]
# ##4. Criar uma matriz de tamanho 5x5 com valores aleatórios e subtrair a média de cada linha dessa matriz

# %%
matriz = np.random.rand(5,5)

med = np.mean(matriz, axis=1)
result = matriz - media[:, np.newaxis]

# %% [markdown]
# ##5. Criar uma matriz de tamanho 4x4 com valores aleatórios e calcular a média e o desvio padrão das diagonais da matriz

# %%
matriz = np.random.rand(4,4)

diagonal = np.diagonal(matriz)
med = np.mean(diagonal)
std = np.std(diagonal)

print(med, std)
# Out:
# 0.4646456202340047 0.17218662460488646
